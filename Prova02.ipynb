# %%
  # !pip install control
# Out:
# Requirement already satisfied: control in /usr/local/lib/python3.10/dist-packages (0.9.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from control) (1.23.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from control) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from control) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->control) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->control) (1.16.0)

# %% [markdown]
# **1)** O retentor de ordem zero (ZOH - zero-order hold) é um sistema utilizado na reconstrução prática
# de sinais em sistemas de conversão digital-analógico. A resposta ao impulso de um retentor de
# ordem zero é apresentada na Figura 1.
#
# **(c)(M)** Obtenha a função de transferência do retentor de ordem zero de forma simbólica. Utilize
# 𝑇 = 1. Compare seus resultados com àqueles obtidos de forma analítica no item (b).

# %%
import sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
  return sympy.laplace_transform(x, t, s, noconds=True)

u0 = sympy.Heaviside(t)
u1 = sympy.Heaviside(t-1)

h = u0 - u1

Laplace(h)
# Out:
#      -s
# 1   ℯ
# ─ - ───
# s    s

# %% [markdown]
# **2)** Determine a transformada de Laplace inversa das funções a seguir. Em todos os casos, considere
# que 𝑓 (𝑡) é causal. Obtenha os resultados de forma analítica e utilizando alguma linguagem de
# programação.

# %% [markdown]
# **a)**$$F(s)=\frac{s+2}{s(s+1)} $$

# %%
import sympy as sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

X = (s+2)/(s*(s+1))
res = invLaplace (X)
res
# Out:
#           -t
# 2⋅θ(t) - ℯ  ⋅θ(t)

# %% [markdown]
# **B)**$$F(s)=\frac{3s^2+4s+2}{s^2+s} $$

# %%
import sympy as sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

X = ((s+2)/(s**2+s)) + 3
res = invLaplace (X)
res
# Out:
#                    -t
# 3⋅δ(t) + 2⋅θ(t) - ℯ  ⋅θ(t)

# %% [markdown]
# **C)**$$F(s)=\frac{2s+13}{s^2+4s+13} $$

# %%
import sympy as sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

X = (2*s+13)/(s**2+4*s+13)
res = invLaplace (X)
res
# Out:
# ⎛   -2⋅t               -2⋅t         ⎞
# ⎝3⋅ℯ    ⋅sin(3⋅t) + 2⋅ℯ    ⋅cos(3⋅t)⎠⋅θ(t)

# %% [markdown]
# **D)**$$F(s)=\frac{s^2-2s+1}{(s-2)(s+1)^2} $$

# %%
import sympy as sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

X = (s**2-2*s+1)/((s-2)*(s+1)**2)
res = invLaplace (X)
res
# Out:
#        -t         2⋅t           -t
#   4⋅t⋅ℯ  ⋅θ(t)   ℯ   ⋅θ(t)   8⋅ℯ  ⋅θ(t)
# - ──────────── + ───────── + ──────────
#        3             9           9

# %% [markdown]
# **3)** Um determinado circuito elétrico possui a seguinte equação diferencial, que relaciona a tensão de entrada $(𝑣𝑖(𝑡))$ e a saída $(𝑣𝑜 (𝑡))$:
# $$\frac{𝑑^2𝑣_𝑜 (𝑡)}{𝑑𝑡^2}+ 7\frac{𝑑𝑣_𝑜 (𝑡)}{𝑑𝑡}+ 10𝑣_𝑜 (𝑡) = \frac{𝑑𝑣_𝑖(𝑡)}{𝑑𝑡}+ 6𝑣_𝑖(𝑡)$$
#
# As condições iniciais para esse circuito são $𝑣𝑜 (0^−) = 6 V$ e $\frac{𝑑𝑣_𝑜 (0^−)}{𝑑𝑡}= −4 V/s$.
#
# **(b)** **(M)** Utilizando um algoritmo de computador e cálculo simbólico, determine a expressão de saída para esse circuito quando a entrada é a mesma da apresentada no item **(a)**. Plote o gráfico de saída.

# %%
import sympy as sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

# %% [markdown]
# Fração Parcial:
# $$V_o = -\frac{9}{s + 3} + \frac{\frac{50}{3}}{s + 2} - \frac{\frac{5}{3}}{s+5}$$

# %%
V_o = -9/(s + 3) + (50/3)/(s + 2) - (5/3)/(s + 5)
invLaplace(V_o)
# Out:
#                   -2⋅t           -3⋅t                          -5⋅t
# 16.6666666666667⋅ℯ    ⋅θ(t) - 9⋅ℯ    ⋅θ(t) - 1.66666666666667⋅ℯ    ⋅θ(t)

# %% [markdown]
# Expressão de saída:
# $$v_o = -9e^{-3t}u(t) + \frac{50}{3}e^{-2t}u(t) - \frac{5}{3}e^{-5t}u(t)$$

# %%
import numpy as np
import matplotlib.pyplot as plt

Ts = 1e-4

tv = np.arange(0,10,Ts)

v_o = -9*np.exp(-3*tv) + (50/3)*np.exp(-2*tv) - (5/3)*np.exp(-5*tv)
plt.grid()
plt.plot(v_o, tv)

# %% [markdown]
# **(e)** **(M)** Utilizando um algoritmo de computador e cáculo simbólico, determine a resposta ao impulso desse sistema (considere as condições iniciais nulas)
#
# Função Transferência:
# $$H(s) = \frac{s + 6}{s^2 + 7s + 10}$$

# %%
import numpy as np
import control as control
import matplotlib.pyplot as plt

num = np.array([1, 6])
den = np.array([1, 7, 10])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([1, 6]), array([ 1,  7, 10]))

# %%
t0 = 0
tend = 15
dt = 1e-4
Npoints = int((tend - t0)/dt)
T = np.linspace(t0,tend,Npoints)

t, h = control.impulse_response(H, T)

plt.plot(t, h)
plt.title("Resposta ao Impulso")
plt.xlabel("$t$")
plt.grid()
plt.show()

# %% [markdown]
# **(g)** **(M)** Utilizando um algoritmo de computador e cálculo simbólico, determine a saída do sistema quando a entrada é o degrau unitário (considere as condições iniciais nulas).
#
# Função Transferência:
# $$H(s) = \frac{s + 6}{s^2 + 7s + 10}$$

# %%
import numpy as np
import control as control
import matplotlib.pyplot as plt

num = np.array([1, 6])
den = np.array([1, 7, 10])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([1, 6]), array([ 1,  7, 10]))

# %%
t0 = 0
tend = 15
dt = 1e-4
Npoints = int((tend - t0)/dt)
T = np.linspace(t0,tend,Npoints)

t, sr = control.step_response(H, T)

plt.plot(t, sr)
plt.title("Resposta ao Degrau")
plt.xlabel("$t$")
plt.grid()
plt.show()

# %% [markdown]
# **4)** Considere um sistema de tempo LTI de tempo contínuo e causal, cuja relação de entrada e saída é descrita pela seguinte equação diferencial:
# $$\ddot{y}(𝑡) + 11\dot{𝑦}(𝑡) + 24𝑦(𝑡) = 5\dot{𝑥}(𝑡) + 3𝑥(𝑡)$$
#
# **(f)** **(M)** Simule esse sistema de tempo contínuo quando a entrada é o degrau unitário. Compare seus resultados com àqueles obtidos nos itens anteriores.

# %%
import sympy as sympy
import control as control
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

# %% [markdown]
# Entrada:
# $$x(t) = u(t)$$
# $$\dot{u}(t) = \delta(t)$$
# $$\mathcal{L}\{u(t)\} = \frac{1}{s}$$
# $$\mathcal{L}\{\delta(t)\} = 1$$
#
# Aplicando a entrada e, a transformada de Laplace em ambos lados da equação diferencial, temos:
# $$
# Y(s)[s^2 + 11s + 24] = 5 + \frac{3}{s}
# $$
#
# ou seja:
#
# $$
# Y(s) = \frac{5s + 3}{s(s^2 + 11s + 24)}
# $$

# %%
Y = (5*s + 3)/(s*(s**2 + 11*s +24))
Y
# Out:
#      5⋅s + 3
# ──────────────────
#   ⎛ 2            ⎞
# s⋅⎝s  + 11⋅s + 24⎠

# %%
y = invLaplace(Y)
y
# Out:
#           -3⋅t            -8⋅t
# θ(t)   4⋅ℯ    ⋅θ(t)   37⋅ℯ    ⋅θ(t)
# ──── + ──────────── - ─────────────
#  8          5               40

# %% [markdown]
# $$\ddot{y}(𝑡) + 11\dot{𝑦}(𝑡) + 24𝑦(𝑡) = 5\dot{𝑥}(𝑡) + 3𝑥(𝑡)$$
#
#
# $$H(s)=\frac{5s+3}{s^2+11s+24}$$

# %%
import control as control
import numpy as np

num = np.array([5, 3])
den = np.array([1, 11, 24])
H = control.tf(num ,den)
H
# Out:
# TransferFunction(array([5, 3]), array([ 1, 11, 24]))

# %%
import matplotlib.pyplot as plt

t0 = 0
tend = 20
td = 1e-4
Npontos = int((tend - t0)/td)
T = np.linspace(t0,tend,Npontos)

t, h = control.step_response(H, T)

plt.plot(t, h)
plt.title('Resposta ao Degrau')
plt.xlabel("$t$")
plt.grid()
plt.show()

# %% [markdown]
# **(g)** **(M)** Utilizando algum algoritmo de computador, apresente o diagrama de polos e zeros para esse sistema e a partir desse, discuta a estabilidade do sistema.

# %% [markdown]
# Aplicando a transformada de Laplace em ambos lados da equação diferencial e considerando as condições iniciais nulas:
#
# $$
# s^2Y(s) + 11sY(s) + 24Y(s) = 5sX(s) + 3X(s)
# $$
#
# Simplicicando:
# $$
# Y(s)[s^2 + 11s + 24] = X(s)[5s + 3]
# $$
#
# ou seja:
#
# $$
# H(s) = \frac{Y(s)}{X(s)} = \frac{s+1}{s^2 + 5s + 6}
# $$

# %%
num = np.array([1, 1])
den = np.array([1 , 5 , 6])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([1, 1]), array([1, 5, 6]))

# %%
control.pzmap(H)
# Out:
# (array([-3.+0.j, -2.+0.j]), array([-1.+0.j]))

# %% [markdown]
# O sistema é estável, poís todos os polos estão no SPE

# %% [markdown]
# **5)** Considere um sistema de tempo LTI de tempo contínuo e causal com a seguinte função de transferência:
# $$𝐻(𝑠) = \frac{2𝑠 + 3}{𝑠^2 + 2𝑠 + 5}$$
#
# **(f)** **(M)** Simule esse sistema de tempo contínuo quando a entrada é o degrau unitário. Compare seus resultados com àqueles obtidos nos itens anteriores.

# %%
import numpy as np
import control as control
import matplotlib.pyplot as plt

num = np.array([2, 3])
den = np.array([1 , 2, 5])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([2, 3]), array([1, 2, 5]))

# %%
t0 = 0
tend = 20
dt = 1e-4
Npontos= int((tend - t0)/dt)
T = np.linspace(t0,tend,Npontos)

t, y = control.step_response(H, T)

plt.plot(t, y)
plt.title('Resposta ao Degrau')
plt.xlabel('$t$')
plt.grid()
plt.show()

# %% [markdown]
# **(g)** **(M)** Utilizando algum algoritmo de computador, apresente o diagrama de polos e zeros para esse sistema e a partir desse, discuta a estabilidade do sistema.

# %%
num = np.array([2, 3])
den = np.array([1 , 2 , 5])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([2, 3]), array([1, 2, 5]))

# %%
control.pzmap(H)
# Out:
# (array([-1.+2.j, -1.-2.j]), array([-1.5+0.j]))

# %% [markdown]
# O sistema é estável, poís todos os polos estão no SPE

# %% [markdown]
# **6)** Um engenheiro deseja modelar um determinado sistema de tempo contínuo. Para isso, aplicou na entrada do sistema o degrau unitário e mediu a saída do sistema. Sabendo que o sistema é de segunda ordem e utilizando softwares para aproximação da saída, ele obteve que a expressão de saída foi: $$𝑦(𝑡) = 𝑒^{−𝑡}𝑢(𝑡) − 𝑒^{−2𝑡}𝑢(𝑡)$$
#
# **(f)** **(M)** Simule esse sistema de tempo contínuo quando a entrada é $𝑥(𝑡) = cos(\sqrt{3}t)𝑢(𝑡)$.Compare seus resultados com àqueles obtidos nos itens anteriores.

# %%
import sympy as sympy
import numpy as np
import control as control
import matplotlib.pyplot as plt
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

# %%
x = sympy.Heaviside(t)
X = Laplace(x)

y = sympy.exp(-t)-sympy.exp(-2*t)
Y = Laplace(y)

H = Y/X
H
# Out:
#        s
# ───────────────
# (s + 1)⋅(s + 2)

# %%
x = sympy.cos(sympy.sqrt(3)*t)
X = Laplace(x)
X
# Out:
#   s
# ──────
#  2
# s  + 3

# %%
Y = H*X
invLaplace(Y)
# Out:
#                                      -t           -2⋅t
# ⎛√3⋅sin(√3⋅t)   9⋅cos(√3⋅t)⎞        ℯ  ⋅θ(t)   4⋅ℯ    ⋅θ(t)
# ⎜──────────── + ───────────⎟⋅θ(t) + ──────── - ────────────
# ⎝     28             28    ⎠           4            7

# %% [markdown]
# Expandido:
# $$H(s)=\frac{s}{s^2+3s+2}$$

# %%
num = np.array([1, 0])
den = np.array([1, 3, 2])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([1, 0]), array([1, 3, 2]))

# %%
t0 = 0
tend = 20
dt = 1e-4
Npoints = int((tend - t0)/dt)
T = np.linspace(t0,tend,Npoints)

x = np.cos(np.sqrt(3)*T)
t, y = control.forced_response(H, T, x)

plt.plot(t, y)
plt.title('Resposta ao cosseno')
plt.xlabel('$t$')
plt.grid()
plt.show()

# %% [markdown]
# **(g)** **(M)** Utilizando algum algoritmo de computador, apresente o diagrama de polos e zeros para esse sistema e a partir desse, discuta a estabilidade do sistema.

# %%
import control as control
import numpy as np

num = np.array([1, 0])
den = np.array([1, 3 , 2])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([1, 0]), array([1, 3, 2]))

# %%
control.pzmap(H)
# Out:
# (array([-2.+0.j, -1.+0.j]), array([0.+0.j]))

# %% [markdown]
# O sistema é estável, poís as raízes estão no SPE.

# %% [markdown]
# **7)** Na Figura 2 é apresentado uma malha de controle utilizando um controlador proporcional cuja função de transferência é:
# $$𝐶(𝑠) = 𝐾$$
# Suponha que a planta possui a seguinte função de transferência:
# $$𝐺(𝑠) = \frac{𝑠 + 1}{(𝑠 − 1) (𝑠 + 4)}$$
# \
# [Figura 2]
#
# **(c)** **(M)** Utilizando algum algoritmo de computador, apresente o diagrama de polos e zeros para esse sistema e a partir desse, discuta a estabilidade do sistema.
# $$G(s)=\frac{s+1}{s^2+3s-4}$$

# %%
import numpy as np
import control as control

num = np.array([1, 1])
den = np.array([1, 3, -4])
G = control.tf(num , den)
G
# Out:
# TransferFunction(array([1, 1]), array([ 1,  3, -4]))

# %%
control.pzmap(G)
# Out:
# (array([-4.+0.j,  1.+0.j]), array([-1.+0.j]))

# %% [markdown]
# Instável, pois uma das raízes está no SPD

# %% [markdown]
# **(e)** **(M)** Simule a saída da planta (sem o sistema de controle) considerando que a entrada é o degrau unitário.

# %%
import sympy as sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

# %%
G = (s + 1)/((s - 1)*(s + 4))

H = G
sympy.simplify(H)
# Out:
#      s + 1
# ───────────────
# (s - 1)⋅(s + 4)

# %%
invLaplace(sympy.simplify(H*(1/s)))
# Out:
#    t                  -4⋅t
# 2⋅ℯ ⋅θ(t)   θ(t)   3⋅ℯ    ⋅θ(t)
# ───────── - ──── - ────────────
#     5        4          20

# %%
import control as control
import numpy as np

num = np.array([1, 1])
den = np.array([1, 4, -3])
H = control.tf(num, den)
H
# Out:
# TransferFunction(array([1, 1]), array([ 1,  4, -3]))

# %%
t0 = 0
tend = 20
dt = 1e-4
Npontos = int((tend - t0)/dt)
T = np.linspace(t0,tend,Npontos)

t, h = control.step_response(H, T)

plt.plot(t, h)
plt.title("Resposta ao Degrau")
plt.xlabel('$t$')
plt.grid()
plt.show()

# %% [markdown]
# **(h)** **(M)** Simule a saída do sistema em malha fechada (com o sistema de controle) quando a referência é o degrau unitário $(𝑟(𝑡) = 𝑢(𝑡))$. Considere o mínimo valor de $𝐾$ inteiro que satisfaça a condição estabelecida por você no item anterior.

# %% [markdown]
# $$H(s) =\frac{C(s)G(s)}{1+C(s)G(s)}$$\
# Para $C(s) = K$ e $𝐺(𝑠) = \frac{𝑠 + 1}{(𝑠 − 1) (𝑠 + 4)}$ ,temos:
#
# $$H(s) = \frac{K\frac{𝑠 + 1}{(𝑠 − 1) (𝑠 + 4)}}{1+K\frac{𝑠 + 1}{(𝑠 − 1) (𝑠 + 4)}}=\frac{Ks+K}{s^2+(3 + K)s+(K - 4)}$$\
# Mínimo valor inteiro de k: 5
# $$H(s)=\frac{5s+5}{s^2+8s+1}$$\
# Como $r(t)=u(t)$, temos:
# $$\mathcal{L}\{r(t)\}=R(s)=\frac{1}{s}$$
# <!-- Logo,
# $$Y(s)=H(s)R(s)=\frac{5s+5}{s^3+8s^2+s}$$ -->

# %%
import sympy as sympy
sympy.init_printing()
t, s = sympy.symbols('t, s')

def Laplace(x):
    return sympy.laplace_transform(x, t, s, noconds=True, simplify=True)

def invLaplace(X):
    return sympy.inverse_laplace_transform(X, s, t)

# %%
K = sympy.symbols('K')

C = K
G = (s + 1)/((s - 1)*(s + 4))

H = C*G/(1 + C*G)
sympy.simplify(H)
# Out:
#          K⋅(s + 1)
# ───────────────────────────
# K⋅(s + 1) + (s - 1)⋅(s + 4)

# %%
C = 5
G = (s + 1)/((s - 1)*(s + 4))

H = C*G/(1 + C*G)
sympy.simplify(H)
# Out:
#  5⋅(s + 1)
# ────────────
#  2
# s  + 8⋅s + 1

# %%
import control as control
import numpy as np

num = np.array([5, 5])
den = np.array([1, 8, 1])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([5, 5]), array([1, 8, 1]))

# %%
import matplotlib.pyplot as plt

t0 = 0
tend = 60
dt = 1e-4
Npoints = int((tend - t0)/dt)
T = np.linspace(t0,tend,Npoints)

t, h = control.step_response(H, T)

plt.plot(t, h)
plt.title("Resposta ao Degrau")
plt.xlabel("$t$")
plt.grid()
plt.show()

# %% [markdown]
# **8)** Dado um sistema de segunda ordem causal cuja função de transferência é dada por:
# $$𝐻(𝑠) =\frac{16}{𝑠^2 + 4𝑠 + 16}$$
#
# **(d)** **(M)** Utilizando algum algoritmo de computador, apresente o diagrama de polos e zeros para esse sistema e a partir desse, discuta a estabilidade do sistema.

# %%
import numpy as np
import control as control

num = np.array([16])
den = np.array([1, 4, 16])
H = control.tf(num, den)
H
# Out:
# TransferFunction(array([16]), array([ 1,  4, 16]))

# %%
control.pzmap(H)
# Out:
# (array([-2.+3.46410162j, -2.-3.46410162j]), array([], dtype=complex128))

# %% [markdown]
# O sistema é estável, isso por que a parte real dos polos são menores que 0, então, os polos estarão no SPE

# %% [markdown]
# **9)** Considere o sistema de controle apresentado na Figura 4. Supondo que deseja-se que o sistema em malha fechada possua um sobressinal máximo de $20\%$ e um tempo de subida de $0,3s$.
# [Figura 4]
#
# **(c)** **(M)** Simule o sistema de controle em malha fechada considerando que a referência é o degrau unitário. Verifique graficamente os valores de tempo de subida, tempo de pico, sobressinal e o tempo de acomodação.
#
# $$H_{eq}(s)=\frac{58,61}{s^2+6,97s+58,61}$$

# %%
import numpy as np
import control as control
import matplotlib.pyplot as plt

num = np.array([58.61])
den = np.array([1, 6.97, 58.61])
H = control.tf(num , den)
H
# Out:
# TransferFunction(array([58.61]), array([ 1.  ,  6.97, 58.61]))

# %%
t0 = 0
tend = 4
dt = 1e-4
Npoints = int((tend - t0)/dt)
T = np.linspace(t0,tend,Npoints)

t, y = control.step_response(H, T)

plt.plot(t, y)
plt.title("Resposta ao Degrau")
plt.xlabel("$t$")
plt.grid()
plt.show()

# %% [markdown]
# **10)** Um engenheiro deseja modelar uma planta através de um modelo de primeira ordem, ou seja:
# $$H(s)= \frac{K}{Ts-1}$$
# Para isso, ele aplicou na entrada da planta o degrau unitário, obtendo a resposta ao degrau apresentada na Figura 5.
#
# **(c)** **(M)** Simule a planta para os valores de $𝑇$ e $𝐾$ encontrados no item anterior. Verifique se a saída possui o mesmo formato da Figura 5.
#
# Para $T = 4$ e $K = 8$, temos:
# $$H(s)=\frac{8}{4s+1}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as control

num = np.array([8])
den = np.array([4, 1])
H = control.tf(num, den)
H
# Out:
# TransferFunction(array([8]), array([4, 1]))

# %%
t0 = 0
tend = 20
dt = 1e-4
Npoints = int((tend - t0)/dt)
T = np.linspace(t0,tend,Npoints)

t, sr = control.step_response(H, T)

plt.plot(t, sr)
plt.title("Resposta ao Degrau")
plt.xlabel("$t$")
plt.grid()
plt.show()
